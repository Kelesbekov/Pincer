# %%
import os
import csv
from collections import defaultdict
import matplotlib.pyplot as plt

# Get the current working directory
current_directory = os.getcwd()

print("Current working directory:", current_directory)

all_items = os.listdir(current_directory)

prefix_to_match = 'P0'
matching_folders = [item for item in all_items if \
                    os.path.isdir(os.path.join(current_directory, item)) \
                    and item.startswith(prefix_to_match)]


#print(matching_folders)

#print(len(matching_folders))

for item in matching_folders:
    folder_path  = os.path.join(current_directory, item)
    #print(folder_path)
    
    

folder_path = 'C:/Users/akira/Desktop/Pincer/P002'


columns_to_keep = ['Pinch Aperture']

for file in os.listdir(folder_path):
    data = []
    file_path = os.path.join(folder_path, file)
    print(file_path)
    with open(file_path, 'r') as file:
        reader = csv.DictReader(file)
        data = [row[col] for col in columns_to_keep for row in reader]

        
        for row in reader:
            data.append(row)
        print(len(data))
        print(data[0])
        plt.figure(figsize=(30,6))
        data = [float(item)*1000 for item in data]
        plt.plot(data)
# Out:
# Current working directory: C:\Users\akira\Desktop\Pincer
# C:/Users/akira/Desktop/Pincer/P002\Participant-02c__take0010__2024-01-12__10-33-43.csv
# 3795
# 0.04976517
# C:/Users/akira/Desktop/Pincer/P002\Participant-02c__take0011__2024-01-12__10-34-41.csv
# 7924
# 0.05796653
# C:/Users/akira/Desktop/Pincer/P002\Participant-02__take0001__2024-01-12__10-48-19.csv
# 5025
# 0.0559096
# C:/Users/akira/Desktop/Pincer/P002\Participant-02__take0002__2024-01-12__10-49-18.csv
# 7843
# 0.07045195
# C:/Users/akira/Desktop/Pincer/P002\Participant-02__take0003__2024-01-12__10-53-46.csv
# 6910
# 0.04644711
# C:/Users/akira/Desktop/Pincer/P002\Participant-02__take0004__2024-01-12__10-55-25.csv
# 7075
# 0.04371053
# C:/Users/akira/Desktop/Pincer/P002\Participant-02__take0005__2024-01-12__10-57-35.csv
# 8472
# 0.03746334
# C:/Users/akira/Desktop/Pincer/P002\Participant-02__take0006__2024-01-12__11-02-57.csv
# 5283
# 0.03946615

# %%
import csv
from collections import defaultdict

# Replace 'your_file.csv' with the actual path to your CSV file
file_path = 'your_file.csv'

# Replace 'split_column' with the actual column name you want to use for splitting
split_column = 'column_to_split'

# Create a dictionary to store data pieces based on the values of the split column
split_data = defaultdict(list)

with open(file_path, 'r') as file:
    reader = csv.DictReader(file)
    
    for row in reader:
        # Extract the value from the specified split column
        split_value = row[split_column]
        
        # Append the entire row to the corresponding split_data list
        split_data[split_value].append(row)

# Now 'split_data' is a dictionary where keys are unique values from the split column,
# and values are lists of dictionaries containing rows with that specific value.
# You can access the split data as needed
for key, value in split_data.items():
    print(f"Data for {split_column} = {key}:")
    for row in value:
        print(row)
    print()
